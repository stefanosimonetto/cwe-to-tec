# %%
import networkx as nx
import matplotlib.pyplot as plt
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim

# %%
import networkx as nx
import pickle
import matplotlib.pyplot as plt
from collections import Counter

# Load graph from pickle file (loaded as a dictionary)
with open('concat/gnn_input.pkl', 'rb') as f:
    graph_dict = pickle.load(f)

# Create a NetworkX graph
graph = nx.Graph()

# %%
# Add nodes to the graph
for node in graph_dict["nodes"]:
    graph.add_node(node['id'], type=node['type'], description_embedding=node['features'].get('description_embedding'))

# Add edges to the graph
for edge in graph_dict["edges"]:
    graph.add_edge(edge['source'], edge['target'], relationship=edge['relationship'])

# Print number of nodes and edges
print("Number of nodes:", graph.number_of_nodes())
print("Number of edges:", graph.number_of_edges())

# Attempting to visualize only two complete chains of CVE -> CWE -> CAPEC -> Technique -> Tactic
# Find two complete chains
complete_chains = []
for edge in graph_dict["edges"]:
    if edge['relationship'] == 'cve_to_cwe':
        cve_node = edge['source']
        cwe_node = edge['target']
        if not graph.has_node(cwe_node):
            continue
        for next_edge in graph_dict["edges"]:
            if next_edge['source'] == cwe_node and next_edge['relationship'] == 'cwe_to_capec':
                capec_node = next_edge['target']
                if not graph.has_node(capec_node):
                    continue
                for next_edge_2 in graph_dict["edges"]:
                    if next_edge_2['source'] == capec_node and next_edge_2['relationship'] == 'capec_to_technique':
                        technique_node = next_edge_2['target']
                        if not graph.has_node(technique_node):
                            continue
                        for next_edge_3 in graph_dict["edges"]:
                            if next_edge_3['source'] == technique_node and next_edge_3['relationship'] == 'technique_to_tactic':
                                tactic_node = next_edge_3['target']
                                if not graph.has_node(tactic_node):
                                    continue
                                complete_chains.append([cve_node, cwe_node, capec_node, technique_node, tactic_node])
                                if len(complete_chains) == 1:
                                    break
                    if len(complete_chains) == 1:
                        break
            if len(complete_chains) == 1:
                break
    if len(complete_chains) == 1:
        break

# Check if complete chains were found
if not complete_chains:
    print("No complete chains found. Please check the data for missing links.")
else:
    # Extract nodes and edges for the complete chains
    selected_nodes = set()
    selected_edges = []
    for chain in complete_chains:
        for i in range(len(chain) - 1):
            selected_nodes.add(chain[i])
            selected_nodes.add(chain[i + 1])
            selected_edges.append((chain[i], chain[i + 1]))

    # Create the subgraph with the selected nodes and edges
    subgraph = nx.Graph()
    subgraph.add_nodes_from((node, graph.nodes[node]) for node in selected_nodes)
    subgraph.add_edges_from(selected_edges)

    # Define colors for different node types
    color_map = []
    for node in subgraph.nodes(data=True):
        node_type = node[1].get('type', 'Unknown')
        if node_type == 'CVE':
            color_map.append('red')
        elif node_type == 'CWE':
            color_map.append('blue')
        elif node_type == 'CAPEC':
            color_map.append('green')
        elif node_type == 'Technique':
            color_map.append('orange')
        elif node_type == 'Tactic':
            color_map.append('purple')
        else:
            color_map.append('grey')

    # Draw the subgraph
    plt.figure(figsize=(12, 12))
    pos = nx.spring_layout(subgraph)  # Layout for positioning the nodes
    nx.draw(subgraph, pos, with_labels=True, node_size=500, edge_color='grey', node_color=color_map)
    plt.title("Visualization of Two Complete Chains: CVE -> CWE -> CAPEC -> Technique -> Tactic")
    plt.show()
# Out:
# Number of nodes: 254204
# Number of edges: 178851

# %%
# Add nodes to the graph
for node in graph_dict["nodes"]:
    graph.add_node(node['id'], type=node['type'], description_embedding=node['features'].get('description_embedding'))

# Add edges to the graph
for edge in graph_dict["edges"]:
    graph.add_edge(edge['source'], edge['target'], relationship=edge['relationship'])

# Print number of nodes and edges
print("Number of nodes:", graph.number_of_nodes())
print("Number of edges:", graph.number_of_edges())

# Find up to 1000 complete chains
complete_chains = []
used_cves = set()  # To track used CVEs

for edge in graph_dict["edges"]:
    if edge['relationship'] == 'cve_to_cwe':
        cve_node = edge['source']
        cwe_node = edge['target']

        print(f"Checking CVE -> CWE: {cve_node} -> {cwe_node}")
        if not graph.has_node(cwe_node):
            print(f"CWE node {cwe_node} does not exist in the graph.")
            continue

        for next_edge in graph_dict["edges"]:
            if next_edge['source'] == cwe_node and next_edge['relationship'] == 'cwe_to_capec':
                capec_node = next_edge['target']
                print(f"Checking CWE -> CAPEC: {cwe_node} -> {capec_node}")
                if not graph.has_node(capec_node):
                    print(f"CAPEC node {capec_node} does not exist in the graph.")
                    continue

                for next_edge_2 in graph_dict["edges"]:
                    if next_edge_2['source'] == capec_node and next_edge_2['relationship'] == 'capec_to_technique':
                        technique_node = next_edge_2['target']
                        print(f"Checking CAPEC -> Technique: {capec_node} -> {technique_node}")
                        if not graph.has_node(technique_node):
                            print(f"Technique node {technique_node} does not exist in the graph.")
                            continue

                        for next_edge_3 in graph_dict["edges"]:
                            if next_edge_3['source'] == technique_node and next_edge_3['relationship'] == 'technique_to_tactic':
                                tactic_node = next_edge_3['target']
                                print(f"Checking Technique -> Tactic: {technique_node} -> {tactic_node}")
                                if not graph.has_node(tactic_node):
                                    print(f"Tactic node {tactic_node} does not exist in the graph.")
                                    continue

                                # Add the chain
                                complete_chains.append([cve_node, cwe_node, capec_node, technique_node, tactic_node])
                                if len(complete_chains) == 50:
                                    break
                    if len(complete_chains) == 50:
                        break
            if len(complete_chains) == 50:
                break
    if len(complete_chains) == 50:
        break

# Filter out chains where a CVE appears more than twice
filtered_chains = []
for chain in complete_chains:
    cve_counts = Counter(node for node in chain if graph.nodes[node].get('type') == 'CVE')
    if all(count <= 2 for count in cve_counts.values()):
        filtered_chains.append(chain)

# Replace complete_chains with filtered_chains
complete_chains = filtered_chains

# Check if complete chains were found
if not complete_chains:
    print("No complete chains found. Please check the data for missing links or duplicate CVEs.")
else:
    # Extract nodes and edges for the complete chains
    selected_nodes = set()
    selected_edges = []
    for chain in complete_chains:
        for i in range(len(chain) - 1):
            selected_nodes.add(chain[i])
            selected_nodes.add(chain[i + 1])
            selected_edges.append((chain[i], chain[i + 1]))

    # Print the complete chains found
    for chain in complete_chains:
        print(f"Complete chain found: {chain}")

    # Create the subgraph with the selected nodes and edges
    subgraph = nx.Graph()
    subgraph.add_nodes_from((node, graph.nodes[node]) for node in selected_nodes)
    subgraph.add_edges_from(selected_edges)

    # Define colors for different node types
    color_map = []
    for node in subgraph.nodes(data=True):
        node_type = node[1].get('type', 'Unknown')
        if node_type == 'CVE':
            color_map.append('red')
        elif node_type == 'CWE':
            color_map.append('blue')
        elif node_type == 'CAPEC':
            color_map.append('green')
        elif node_type == 'TECHNIQUE':
            color_map.append('orange')
        elif node_type == 'TACTIC':
            color_map.append('purple')
        else:
            color_map.append('grey')

    # Plot the subgraph
    plt.figure(figsize=(12, 12))
    pos = nx.spring_layout(subgraph)  # Layout for positioning the nodes
    nx.draw(subgraph, pos, with_labels=True, node_size=500, edge_color='grey', node_color=color_map)
    plt.title("Visualization of Complete Chains (Filtered for CVE Usage): CVE -> CWE -> CAPEC -> Technique -> Tactic")
    plt.show()
# Out:
# Number of nodes: 254204
# Number of edges: 178851
# Checking CVE -> CWE: CVE-1999-0001 -> CWE-20
# Checking CWE -> CAPEC: CWE-20 -> CAPEC-13
# Checking CAPEC -> Technique: CAPEC-13 -> T1562.003
# Checking Technique -> Tactic: T1562.003 -> TA0005
# Checking CAPEC -> Technique: CAPEC-13 -> T1574.006
# Checking Technique -> Tactic: T1574.006 -> TA0003
# Checking Technique -> Tactic: T1574.006 -> TA0004
# Checking Technique -> Tactic: T1574.006 -> TA0005
# Checking CAPEC -> Technique: CAPEC-13 -> T1574.007
# Checking Technique -> Tactic: T1574.007 -> TA0003
# Checking Technique -> Tactic: T1574.007 -> TA0004
# Checking Technique -> Tactic: T1574.007 -> TA0005
# Checking CWE -> CAPEC: CWE-20 -> CAPEC-267
# Checking CAPEC -> Technique: CAPEC-267 -> T1027
# Checking Technique -> Tactic: T1027 -> TA0005
# Checking CWE -> CAPEC: CWE-20 -> CAPEC-31
# Checking CAPEC -> Technique: CAPEC-31 -> T1539
# Checking Technique -> Tactic: T1539 -> TA0006
# Checking CWE -> CAPEC: CWE-20 -> CAPEC-473
# Checking CAPEC -> Technique: CAPEC-473 -> T1036.001
# Checking Technique -> Tactic: T1036.001 -> TA0005
# Checking CAPEC -> Technique: CAPEC-473 -> T1553.002
# Checking Technique -> Tactic: T1553.002 -> TA0005
# Checking CVE -> CWE: CVE-1999-0002 -> CWE-119
# Checking CVE -> CWE: CVE-1999-0007 -> CWE-327
# Checking CWE -> CAPEC: CWE-327 -> CAPEC-473
# Checking CAPEC -> Technique: CAPEC-473 -> T1036.001
# Checking Technique -> Tactic: T1036.001 -> TA0005
# Checking CAPEC -> Technique: CAPEC-473 -> T1553.002
# Checking Technique -> Tactic: T1553.002 -> TA0005
# Checking CVE -> CWE: CVE-1999-0027 -> CWE-119
# Checking CVE -> CWE: CVE-1999-0067 -> CWE-78
# Checking CVE -> CWE: CVE-1999-0179 -> CWE-17
# Checking CVE -> CWE: CVE-1999-0199 -> CWE-252
# Checking CVE -> CWE: CVE-1999-0226 -> CWE-19
# Checking CVE -> CWE: CVE-1999-0227 -> CWE-264
# Checking CVE -> CWE: CVE-1999-0236 -> CWE-200
# Checking CWE -> CAPEC: CWE-200 -> CAPEC-13
# Checking CAPEC -> Technique: CAPEC-13 -> T1562.003
# Checking Technique -> Tactic: T1562.003 -> TA0005
# Checking CAPEC -> Technique: CAPEC-13 -> T1574.006
# Checking Technique -> Tactic: T1574.006 -> TA0003
# Checking Technique -> Tactic: T1574.006 -> TA0004
# Checking Technique -> Tactic: T1574.006 -> TA0005
# Checking CAPEC -> Technique: CAPEC-13 -> T1574.007
# Checking Technique -> Tactic: T1574.007 -> TA0003
# Checking Technique -> Tactic: T1574.007 -> TA0004
# Checking Technique -> Tactic: T1574.007 -> TA0005
# Checking CWE -> CAPEC: CWE-200 -> CAPEC-169
# Checking CAPEC -> Technique: CAPEC-169 -> T1217
# Checking Technique -> Tactic: T1217 -> TA0007
# Checking CAPEC -> Technique: CAPEC-169 -> T1592
# Checking Technique -> Tactic: T1592 -> TA0043
# Checking CAPEC -> Technique: CAPEC-169 -> T1595
# Checking Technique -> Tactic: T1595 -> TA0043
# Checking CWE -> CAPEC: CWE-200 -> CAPEC-292
# Checking CAPEC -> Technique: CAPEC-292 -> T1018
# Checking Technique -> Tactic: T1018 -> TA0007
# Checking CWE -> CAPEC: CWE-200 -> CAPEC-295
# Checking CAPEC -> Technique: CAPEC-295 -> T1124
# Checking Technique -> Tactic: T1124 -> TA0007
# Checking CWE -> CAPEC: CWE-200 -> CAPEC-300
# Checking CAPEC -> Technique: CAPEC-300 -> T1046
# Checking Technique -> Tactic: T1046 -> TA0007
# Checking CWE -> CAPEC: CWE-200 -> CAPEC-309
# Checking CAPEC -> Technique: CAPEC-309 -> T1016
# Checking Technique -> Tactic: T1016 -> TA0007
# Checking CAPEC -> Technique: CAPEC-309 -> T1049
# Checking Technique -> Tactic: T1049 -> TA0007
# Checking CAPEC -> Technique: CAPEC-309 -> T1590
# Checking Technique -> Tactic: T1590 -> TA0043
# Checking CWE -> CAPEC: CWE-200 -> CAPEC-312
# Checking CAPEC -> Technique: CAPEC-312 -> T1082
# Checking Technique -> Tactic: T1082 -> TA0007
# Checking CWE -> CAPEC: CWE-200 -> CAPEC-313
# Checking CAPEC -> Technique: CAPEC-313 -> T1082
# Checking Technique -> Tactic: T1082 -> TA0007
# Checking CWE -> CAPEC: CWE-200 -> CAPEC-497
# Checking CAPEC -> Technique: CAPEC-497 -> T1083
# Checking Technique -> Tactic: T1083 -> TA0007
# Checking CWE -> CAPEC: CWE-200 -> CAPEC-573
# Checking CAPEC -> Technique: CAPEC-573 -> T1057
# Checking Technique -> Tactic: T1057 -> TA0007
# Checking CWE -> CAPEC: CWE-200 -> CAPEC-574
# Checking CAPEC -> Technique: CAPEC-574 -> T1007
# Checking Technique -> Tactic: T1007 -> TA0007
# Checking CWE -> CAPEC: CWE-200 -> CAPEC-575
# Checking CAPEC -> Technique: CAPEC-575 -> T1087
# Checking Technique -> Tactic: T1087 -> TA0007
# Checking CWE -> CAPEC: CWE-200 -> CAPEC-576
# Checking CAPEC -> Technique: CAPEC-576 -> T1069
# Checking Technique -> Tactic: T1069 -> TA0007
# Checking CAPEC -> Technique: CAPEC-576 -> T1615
# Checking Technique -> Tactic: T1615 -> TA0007
# Checking CWE -> CAPEC: CWE-200 -> CAPEC-577
# Checking CAPEC -> Technique: CAPEC-577 -> T1033
# Checking Technique -> Tactic: T1033 -> TA0007
# Checking CWE -> CAPEC: CWE-200 -> CAPEC-60
# Checking CAPEC -> Technique: CAPEC-60 -> T1134.001
# Checking Technique -> Tactic: T1134.001 -> TA0005
# Checking Technique -> Tactic: T1134.001 -> TA0004
# Checking CAPEC -> Technique: CAPEC-60 -> T1550.004
# Checking Technique -> Tactic: T1550.004 -> TA0005
# Checking Technique -> Tactic: T1550.004 -> TA0008
# Checking CWE -> CAPEC: CWE-200 -> CAPEC-616
# Checking CAPEC -> Technique: CAPEC-616 -> T1036.005
# Checking Technique -> Tactic: T1036.005 -> TA0005
# Checking CWE -> CAPEC: CWE-200 -> CAPEC-643
# Checking CAPEC -> Technique: CAPEC-643 -> T1135
# Checking Technique -> Tactic: T1135 -> TA0007
# Checking CWE -> CAPEC: CWE-200 -> CAPEC-646
# Checking CAPEC -> Technique: CAPEC-646 -> T1120
# Checking Technique -> Tactic: T1120 -> TA0007
# Checking CWE -> CAPEC: CWE-200 -> CAPEC-651
# Checking CAPEC -> Technique: CAPEC-651 -> T1111
# Checking Technique -> Tactic: T1111 -> TA0006
# Checking CVE -> CWE: CVE-1999-0265 -> CWE-20
# Checking CWE -> CAPEC: CWE-20 -> CAPEC-13
# Checking CAPEC -> Technique: CAPEC-13 -> T1562.003
# Checking Technique -> Tactic: T1562.003 -> TA0005
# Checking CAPEC -> Technique: CAPEC-13 -> T1574.006
# Checking Technique -> Tactic: T1574.006 -> TA0003
# Checking Technique -> Tactic: T1574.006 -> TA0004
# Checking Technique -> Tactic: T1574.006 -> TA0005
# Complete chain found: ['CVE-1999-0001', 'CWE-20', 'CAPEC-13', 'T1562.003', 'TA0005']
# Complete chain found: ['CVE-1999-0001', 'CWE-20', 'CAPEC-13', 'T1574.006', 'TA0003']
# Complete chain found: ['CVE-1999-0001', 'CWE-20', 'CAPEC-13', 'T1574.006', 'TA0004']
# Complete chain found: ['CVE-1999-0001', 'CWE-20', 'CAPEC-13', 'T1574.006', 'TA0005']
# Complete chain found: ['CVE-1999-0001', 'CWE-20', 'CAPEC-13', 'T1574.007', 'TA0003']
# Complete chain found: ['CVE-1999-0001', 'CWE-20', 'CAPEC-13', 'T1574.007', 'TA0004']
# Complete chain found: ['CVE-1999-0001', 'CWE-20', 'CAPEC-13', 'T1574.007', 'TA0005']
# Complete chain found: ['CVE-1999-0001', 'CWE-20', 'CAPEC-267', 'T1027', 'TA0005']
# Complete chain found: ['CVE-1999-0001', 'CWE-20', 'CAPEC-31', 'T1539', 'TA0006']
# Complete chain found: ['CVE-1999-0001', 'CWE-20', 'CAPEC-473', 'T1036.001', 'TA0005']
# Complete chain found: ['CVE-1999-0001', 'CWE-20', 'CAPEC-473', 'T1553.002', 'TA0005']
# Complete chain found: ['CVE-1999-0007', 'CWE-327', 'CAPEC-473', 'T1036.001', 'TA0005']
# Complete chain found: ['CVE-1999-0007', 'CWE-327', 'CAPEC-473', 'T1553.002', 'TA0005']
# Complete chain found: ['CVE-1999-0236', 'CWE-200', 'CAPEC-13', 'T1562.003', 'TA0005']
# Complete chain found: ['CVE-1999-0236', 'CWE-200', 'CAPEC-13', 'T1574.006', 'TA0003']
# Complete chain found: ['CVE-1999-0236', 'CWE-200', 'CAPEC-13', 'T1574.006', 'TA0004']
# Complete chain found: ['CVE-1999-0236', 'CWE-200', 'CAPEC-13', 'T1574.006', 'TA0005']
# Complete chain found: ['CVE-1999-0236', 'CWE-200', 'CAPEC-13', 'T1574.007', 'TA0003']
# Complete chain found: ['CVE-1999-0236', 'CWE-200', 'CAPEC-13', 'T1574.007', 'TA0004']
# Complete chain found: ['CVE-1999-0236', 'CWE-200', 'CAPEC-13', 'T1574.007', 'TA0005']
# Complete chain found: ['CVE-1999-0236', 'CWE-200', 'CAPEC-169', 'T1217', 'TA0007']
# Complete chain found: ['CVE-1999-0236', 'CWE-200', 'CAPEC-169', 'T1592', 'TA0043']
# Complete chain found: ['CVE-1999-0236', 'CWE-200', 'CAPEC-169', 'T1595', 'TA0043']
# Complete chain found: ['CVE-1999-0236', 'CWE-200', 'CAPEC-292', 'T1018', 'TA0007']
# Complete chain found: ['CVE-1999-0236', 'CWE-200', 'CAPEC-295', 'T1124', 'TA0007']
# Complete chain found: ['CVE-1999-0236', 'CWE-200', 'CAPEC-300', 'T1046', 'TA0007']
# Complete chain found: ['CVE-1999-0236', 'CWE-200', 'CAPEC-309', 'T1016', 'TA0007']
# Complete chain found: ['CVE-1999-0236', 'CWE-200', 'CAPEC-309', 'T1049', 'TA0007']
# Complete chain found: ['CVE-1999-0236', 'CWE-200', 'CAPEC-309', 'T1590', 'TA0043']
# Complete chain found: ['CVE-1999-0236', 'CWE-200', 'CAPEC-312', 'T1082', 'TA0007']
# Complete chain found: ['CVE-1999-0236', 'CWE-200', 'CAPEC-313', 'T1082', 'TA0007']
# Complete chain found: ['CVE-1999-0236', 'CWE-200', 'CAPEC-497', 'T1083', 'TA0007']
# Complete chain found: ['CVE-1999-0236', 'CWE-200', 'CAPEC-573', 'T1057', 'TA0007']
# Complete chain found: ['CVE-1999-0236', 'CWE-200', 'CAPEC-574', 'T1007', 'TA0007']
# Complete chain found: ['CVE-1999-0236', 'CWE-200', 'CAPEC-575', 'T1087', 'TA0007']
# Complete chain found: ['CVE-1999-0236', 'CWE-200', 'CAPEC-576', 'T1069', 'TA0007']
# Complete chain found: ['CVE-1999-0236', 'CWE-200', 'CAPEC-576', 'T1615', 'TA0007']
# Complete chain found: ['CVE-1999-0236', 'CWE-200', 'CAPEC-577', 'T1033', 'TA0007']
# Complete chain found: ['CVE-1999-0236', 'CWE-200', 'CAPEC-60', 'T1134.001', 'TA0005']
# Complete chain found: ['CVE-1999-0236', 'CWE-200', 'CAPEC-60', 'T1134.001', 'TA0004']
# Complete chain found: ['CVE-1999-0236', 'CWE-200', 'CAPEC-60', 'T1550.004', 'TA0005']
# Complete chain found: ['CVE-1999-0236', 'CWE-200', 'CAPEC-60', 'T1550.004', 'TA0008']
# Complete chain found: ['CVE-1999-0236', 'CWE-200', 'CAPEC-616', 'T1036.005', 'TA0005']
# Complete chain found: ['CVE-1999-0236', 'CWE-200', 'CAPEC-643', 'T1135', 'TA0007']
# Complete chain found: ['CVE-1999-0236', 'CWE-200', 'CAPEC-646', 'T1120', 'TA0007']
# Complete chain found: ['CVE-1999-0236', 'CWE-200', 'CAPEC-651', 'T1111', 'TA0006']
# Complete chain found: ['CVE-1999-0265', 'CWE-20', 'CAPEC-13', 'T1562.003', 'TA0005']
# Complete chain found: ['CVE-1999-0265', 'CWE-20', 'CAPEC-13', 'T1574.006', 'TA0003']
# Complete chain found: ['CVE-1999-0265', 'CWE-20', 'CAPEC-13', 'T1574.006', 'TA0004']
# Complete chain found: ['CVE-1999-0265', 'CWE-20', 'CAPEC-13', 'T1574.006', 'TA0005']

# %%
for node in graph_dict["nodes"]:
    graph.add_node(node['id'], type=node['type'], description_embedding=node['features'].get('description_embedding'))

# Add edges to the graph
for edge in graph_dict["edges"]:
    graph.add_edge(edge['source'], edge['target'], relationship=edge['relationship'])

# Print number of nodes and edges
print("Number of nodes:", graph.number_of_nodes())
print("Number of edges:", graph.number_of_edges())

# Find up to 1000 complete chains using only CVE nodes with ID CVE-2023
complete_chains = []

for edge in graph_dict["edges"]:
    if edge['relationship'] == 'cve_to_cwe':
        cve_node = edge['source']
        cwe_node = edge['target']

        # Skip if this CVE node does not start with "CVE-2023"
        if not cve_node.startswith("CVE-2023"):
            continue

        print(f"Checking CVE -> CWE: {cve_node} -> {cwe_node}")
        if not graph.has_node(cwe_node):
            print(f"CWE node {cwe_node} does not exist in the graph.")
            continue

        for next_edge in graph_dict["edges"]:
            if next_edge['source'] == cwe_node and next_edge['relationship'] == 'cwe_to_capec':
                capec_node = next_edge['target']
                print(f"Checking CWE -> CAPEC: {cwe_node} -> {capec_node}")
                if not graph.has_node(capec_node):
                    print(f"CAPEC node {capec_node} does not exist in the graph.")
                    continue

                for next_edge_2 in graph_dict["edges"]:
                    if next_edge_2['source'] == capec_node and next_edge_2['relationship'] == 'capec_to_technique':
                        technique_node = next_edge_2['target']
                        print(f"Checking CAPEC -> Technique: {capec_node} -> {technique_node}")
                        if not graph.has_node(technique_node):
                            print(f"Technique node {technique_node} does not exist in the graph.")
                            continue

                        for next_edge_3 in graph_dict["edges"]:
                            if next_edge_3['source'] == technique_node and next_edge_3['relationship'] == 'technique_to_tactic':
                                tactic_node = next_edge_3['target']
                                print(f"Checking Technique -> Tactic: {technique_node} -> {tactic_node}")
                                if not graph.has_node(tactic_node):
                                    print(f"Tactic node {tactic_node} does not exist in the graph.")
                                    continue

                                # Add the chain
                                complete_chains.append([cve_node, cwe_node, capec_node, technique_node, tactic_node])
                                if len(complete_chains) == 100:
                                    break
                    if len(complete_chains) == 100:
                        break
            if len(complete_chains) == 100:
                break
    if len(complete_chains) == 100:
        break

# Filter out chains where a CVE appears more than twice
filtered_chains = []
for chain in complete_chains:
    cve_counts = Counter(node for node in chain if graph.nodes[node].get('type') == 'CVE')
    if all(count <= 2 for count in cve_counts.values()):
        filtered_chains.append(chain)

# Replace complete_chains with filtered_chains
complete_chains = filtered_chains

# Check if complete chains were found
if not complete_chains:
    print("No complete chains found. Please check the data for missing links or duplicate CVEs.")
else:
    # Extract nodes and edges for the complete chains
    selected_nodes = set()
    selected_edges = []
    for chain in complete_chains:
        for i in range(len(chain) - 1):
            selected_nodes.add(chain[i])
            selected_nodes.add(chain[i + 1])
            selected_edges.append((chain[i], chain[i + 1]))

    # Create the subgraph with the selected nodes and edges
    subgraph = nx.Graph()
    subgraph.add_nodes_from((node, graph.nodes[node]) for node in selected_nodes)
    subgraph.add_edges_from(selected_edges)

    # Define colors for different node types
    color_map = []
    for node in subgraph.nodes(data=True):
        node_type = node[1].get('type', 'Unknown')
        if node_type == 'CVE':
            color_map.append('red')
        elif node_type == 'CWE':
            color_map.append('blue')
        elif node_type == 'CAPEC':
            color_map.append('green')
        elif node_type == 'TECHNIQUE':
            color_map.append('orange')
        elif node_type == 'TACTIC':
            color_map.append('purple')
        else:
            color_map.append('grey')

    # Define a custom layout with CVE nodes on the left
    pos = nx.spring_layout(subgraph)  # Start with a spring layout
    for node, attributes in subgraph.nodes(data=True):
        pos[node] = (0.5, pos[node][1]) 
        if attributes.get('type') == 'CVE':
            pos[node] = (-1.0, pos[node][1])  # Place CVE nodes on the left
        if attributes.get('type') == 'CWE':
            pos[node] = (-0.5, pos[node][1])
        if attributes.get('type') == 'CAPEC':
            pos[node] = (0, pos[node][1])
        if attributes.get('type') == 'TECNIQUE':
            pos[node] = (1, pos[node][1])
        if attributes.get('type') == 'TACTIC':
            pos[node] = (1.0, pos[node][1])
    # Plot the subgraph
    plt.figure(figsize=(12, 12))
    nx.draw(subgraph, pos, with_labels=True, node_size=500, edge_color='grey', node_color=color_map)
    plt.title("Visualization of Complete Chains (CVE on the Left): CVE -> CWE -> CAPEC -> Technique -> Tactic")
    plt.show()
# Out:
# Number of nodes: 254204
# Number of edges: 178851
# Checking CVE -> CWE: CVE-2023-0001 -> CWE-319
# Checking CWE -> CAPEC: CWE-319 -> CAPEC-383
# Checking CAPEC -> Technique: CAPEC-383 -> T1056.004
# Checking Technique -> Tactic: T1056.004 -> TA0009
# Checking Technique -> Tactic: T1056.004 -> TA0006
# Checking CWE -> CAPEC: CWE-319 -> CAPEC-65
# Checking CAPEC -> Technique: CAPEC-65 -> T1040
# Checking Technique -> Tactic: T1040 -> TA0006
# Checking Technique -> Tactic: T1040 -> TA0007
# Checking CVE -> CWE: CVE-2023-0003 -> CWE-610
# Checking CVE -> CWE: CVE-2023-0005 -> CWE-312
# Checking CWE -> CAPEC: CWE-312 -> CAPEC-37
# Checking CAPEC -> Technique: CAPEC-37 -> T1005
# Checking Technique -> Tactic: T1005 -> TA0009
# Checking CAPEC -> Technique: CAPEC-37 -> T1552.004
# Checking Technique -> Tactic: T1552.004 -> TA0006
# Checking CVE -> CWE: CVE-2023-0006 -> CWE-367
# Checking CVE -> CWE: CVE-2023-0007 -> CWE-79
# Checking CVE -> CWE: CVE-2023-0008 -> CWE-610
# Checking CVE -> CWE: CVE-2023-0010 -> CWE-79
# Checking CVE -> CWE: CVE-2023-0011 -> CWE-78
# Checking CVE -> CWE: CVE-2023-0012 -> CWE-284
# Checking CWE -> CAPEC: CWE-284 -> CAPEC-19
# Checking CAPEC -> Technique: CAPEC-19 -> T1027.009
# Checking Technique -> Tactic: T1027.009 -> TA0005
# Checking CAPEC -> Technique: CAPEC-19 -> T1546.004
# Checking Technique -> Tactic: T1546.004 -> TA0004
# Checking Technique -> Tactic: T1546.004 -> TA0003
# Checking CAPEC -> Technique: CAPEC-19 -> T1546.016
# Checking Technique -> Tactic: T1546.016 -> TA0004
# Checking Technique -> Tactic: T1546.016 -> TA0003
# Checking CWE -> CAPEC: CWE-284 -> CAPEC-478
# Checking CAPEC -> Technique: CAPEC-478 -> T1574.011
# Checking Technique -> Tactic: T1574.011 -> TA0003
# Checking Technique -> Tactic: T1574.011 -> TA0004
# Checking Technique -> Tactic: T1574.011 -> TA0005
# Checking CAPEC -> Technique: CAPEC-478 -> T1543.003
# Checking Technique -> Tactic: T1543.003 -> TA0003
# Checking Technique -> Tactic: T1543.003 -> TA0004
# Checking CWE -> CAPEC: CWE-284 -> CAPEC-479
# Checking CAPEC -> Technique: CAPEC-479 -> T1553.004
# Checking Technique -> Tactic: T1553.004 -> TA0005
# Checking CWE -> CAPEC: CWE-284 -> CAPEC-550
# Checking CAPEC -> Technique: CAPEC-550 -> T1543
# Checking Technique -> Tactic: T1543 -> TA0003
# Checking Technique -> Tactic: T1543 -> TA0004
# Checking CWE -> CAPEC: CWE-284 -> CAPEC-551
# Checking CAPEC -> Technique: CAPEC-551 -> T1543
# Checking Technique -> Tactic: T1543 -> TA0003
# Checking Technique -> Tactic: T1543 -> TA0004
# Checking CWE -> CAPEC: CWE-284 -> CAPEC-552
# Checking CAPEC -> Technique: CAPEC-552 -> T1014
# Checking Technique -> Tactic: T1014 -> TA0005
# Checking CAPEC -> Technique: CAPEC-552 -> T1542.003
# Checking Technique -> Tactic: T1542.003 -> TA0003
# Checking Technique -> Tactic: T1542.003 -> TA0005
# Checking CAPEC -> Technique: CAPEC-552 -> T1547.006
# Checking Technique -> Tactic: T1547.006 -> TA0003
# Checking Technique -> Tactic: T1547.006 -> TA0004
# Checking CWE -> CAPEC: CWE-284 -> CAPEC-556
# Checking CAPEC -> Technique: CAPEC-556 -> T1546.001
# Checking Technique -> Tactic: T1546.001 -> TA0004
# Checking Technique -> Tactic: T1546.001 -> TA0003
# Checking CWE -> CAPEC: CWE-284 -> CAPEC-558
# Checking CAPEC -> Technique: CAPEC-558 -> T1505.005
# Checking Technique -> Tactic: T1505.005 -> TA0003
# Checking CAPEC -> Technique: CAPEC-558 -> T1546.008
# Checking Technique -> Tactic: T1546.008 -> TA0004
# Checking Technique -> Tactic: T1546.008 -> TA0003
# Checking CWE -> CAPEC: CWE-284 -> CAPEC-562
# Checking CAPEC -> Technique: CAPEC-562 -> T1080
# Checking Technique -> Tactic: T1080 -> TA0008
# Checking CWE -> CAPEC: CWE-284 -> CAPEC-564
# Checking CAPEC -> Technique: CAPEC-564 -> T1037
# Checking Technique -> Tactic: T1037 -> TA0003
# Checking Technique -> Tactic: T1037 -> TA0004
# Checking CAPEC -> Technique: CAPEC-564 -> T1543.001
# Checking Technique -> Tactic: T1543.001 -> TA0003
# Checking Technique -> Tactic: T1543.001 -> TA0004
# Checking CAPEC -> Technique: CAPEC-564 -> T1543.004
# Checking Technique -> Tactic: T1543.004 -> TA0003
# Checking Technique -> Tactic: T1543.004 -> TA0004
# Checking CAPEC -> Technique: CAPEC-564 -> T1547
# Checking Technique -> Tactic: T1547 -> TA0003
# Checking Technique -> Tactic: T1547 -> TA0004
# Checking CWE -> CAPEC: CWE-284 -> CAPEC-578
# Checking CAPEC -> Technique: CAPEC-578 -> T1556.006
# Checking Technique -> Tactic: T1556.006 -> TA0006
# Checking Technique -> Tactic: T1556.006 -> TA0005
# Checking Technique -> Tactic: T1556.006 -> TA0003
# Checking CAPEC -> Technique: CAPEC-578 -> T1562.001
# Checking Technique -> Tactic: T1562.001 -> TA0005
# Checking CAPEC -> Technique: CAPEC-578 -> T1562.002
# Checking Technique -> Tactic: T1562.002 -> TA0005
# Checking CAPEC -> Technique: CAPEC-578 -> T1562.004
# Checking Technique -> Tactic: T1562.004 -> TA0005
# Checking CAPEC -> Technique: CAPEC-578 -> T1562.007
# Checking Technique -> Tactic: T1562.007 -> TA0005
# Checking CAPEC -> Technique: CAPEC-578 -> T1562.008
# Checking Technique -> Tactic: T1562.008 -> TA0005
# Checking CAPEC -> Technique: CAPEC-578 -> T1562.009
# Checking Technique -> Tactic: T1562.009 -> TA0005
# Checking CVE -> CWE: CVE-2023-0013 -> CWE-79
# Checking CVE -> CWE: CVE-2023-0014 -> CWE-294
# Checking CWE -> CAPEC: CWE-294 -> CAPEC-509
# Checking CAPEC -> Technique: CAPEC-509 -> T1558.003
# Checking Technique -> Tactic: T1558.003 -> TA0006
# Checking CWE -> CAPEC: CWE-294 -> CAPEC-555
# Checking CAPEC -> Technique: CAPEC-555 -> T1021
# Checking Technique -> Tactic: T1021 -> TA0008
# Checking CAPEC -> Technique: CAPEC-555 -> T1114.002
# Checking Technique -> Tactic: T1114.002 -> TA0009
# Checking CAPEC -> Technique: CAPEC-555 -> T1133
# Checking Technique -> Tactic: T1133 -> TA0003
# Checking Technique -> Tactic: T1133 -> TA0001
# Checking CWE -> CAPEC: CWE-294 -> CAPEC-561
# Checking CAPEC -> Technique: CAPEC-561 -> T1021.002
# Checking Technique -> Tactic: T1021.002 -> TA0008
# Checking CWE -> CAPEC: CWE-294 -> CAPEC-60
# Checking CAPEC -> Technique: CAPEC-60 -> T1134.001
# Checking Technique -> Tactic: T1134.001 -> TA0005
# Checking Technique -> Tactic: T1134.001 -> TA0004
# Checking CAPEC -> Technique: CAPEC-60 -> T1550.004
# Checking Technique -> Tactic: T1550.004 -> TA0005
# Checking Technique -> Tactic: T1550.004 -> TA0008
# Checking CWE -> CAPEC: CWE-294 -> CAPEC-644
# Checking CAPEC -> Technique: CAPEC-644 -> T1550.002
# Checking Technique -> Tactic: T1550.002 -> TA0005
# Checking Technique -> Tactic: T1550.002 -> TA0008
# Checking CWE -> CAPEC: CWE-294 -> CAPEC-645
# Checking CAPEC -> Technique: CAPEC-645 -> T1550.003
# Checking Technique -> Tactic: T1550.003 -> TA0005
# Checking Technique -> Tactic: T1550.003 -> TA0008
# Checking CWE -> CAPEC: CWE-294 -> CAPEC-652
# Checking CAPEC -> Technique: CAPEC-652 -> T1558
# Checking Technique -> Tactic: T1558 -> TA0006
# Checking CWE -> CAPEC: CWE-294 -> CAPEC-94
# Checking CAPEC -> Technique: CAPEC-94 -> T1557
# Checking Technique -> Tactic: T1557 -> TA0006
# Checking Technique -> Tactic: T1557 -> TA0009
# Checking CVE -> CWE: CVE-2023-0015 -> CWE-79
# Checking CVE -> CWE: CVE-2023-0016 -> CWE-89
# Checking CVE -> CWE: CVE-2023-0017 -> CWE-284
# Checking CWE -> CAPEC: CWE-284 -> CAPEC-19
# Checking CAPEC -> Technique: CAPEC-19 -> T1027.009
# Checking Technique -> Tactic: T1027.009 -> TA0005
# Checking CAPEC -> Technique: CAPEC-19 -> T1546.004
# Checking Technique -> Tactic: T1546.004 -> TA0004
# Checking Technique -> Tactic: T1546.004 -> TA0003
# Checking CAPEC -> Technique: CAPEC-19 -> T1546.016
# Checking Technique -> Tactic: T1546.016 -> TA0004
# Checking Technique -> Tactic: T1546.016 -> TA0003
# Checking CWE -> CAPEC: CWE-284 -> CAPEC-478
# Checking CAPEC -> Technique: CAPEC-478 -> T1574.011
# Checking Technique -> Tactic: T1574.011 -> TA0003
# Checking Technique -> Tactic: T1574.011 -> TA0004
# Checking Technique -> Tactic: T1574.011 -> TA0005
# Checking CAPEC -> Technique: CAPEC-478 -> T1543.003
# Checking Technique -> Tactic: T1543.003 -> TA0003
# Checking Technique -> Tactic: T1543.003 -> TA0004
# Checking CWE -> CAPEC: CWE-284 -> CAPEC-479
# Checking CAPEC -> Technique: CAPEC-479 -> T1553.004
# Checking Technique -> Tactic: T1553.004 -> TA0005
# Checking CWE -> CAPEC: CWE-284 -> CAPEC-550
# Checking CAPEC -> Technique: CAPEC-550 -> T1543
# Checking Technique -> Tactic: T1543 -> TA0003
# Checking Technique -> Tactic: T1543 -> TA0004
# Checking CWE -> CAPEC: CWE-284 -> CAPEC-551
# Checking CAPEC -> Technique: CAPEC-551 -> T1543
# Checking Technique -> Tactic: T1543 -> TA0003
# Checking Technique -> Tactic: T1543 -> TA0004
# Checking CWE -> CAPEC: CWE-284 -> CAPEC-552
# Checking CAPEC -> Technique: CAPEC-552 -> T1014
# Checking Technique -> Tactic: T1014 -> TA0005
# Checking CAPEC -> Technique: CAPEC-552 -> T1542.003
# Checking Technique -> Tactic: T1542.003 -> TA0003
# Checking Technique -> Tactic: T1542.003 -> TA0005
# Checking CAPEC -> Technique: CAPEC-552 -> T1547.006
# Checking Technique -> Tactic: T1547.006 -> TA0003
# Checking Technique -> Tactic: T1547.006 -> TA0004
# Checking CWE -> CAPEC: CWE-284 -> CAPEC-556
# Checking CAPEC -> Technique: CAPEC-556 -> T1546.001
# Checking Technique -> Tactic: T1546.001 -> TA0004
# Checking Technique -> Tactic: T1546.001 -> TA0003
# Checking CWE -> CAPEC: CWE-284 -> CAPEC-558
# Checking CAPEC -> Technique: CAPEC-558 -> T1505.005
# Checking Technique -> Tactic: T1505.005 -> TA0003
# Checking CAPEC -> Technique: CAPEC-558 -> T1546.008
# Checking Technique -> Tactic: T1546.008 -> TA0004
# Checking Technique -> Tactic: T1546.008 -> TA0003
# Checking CWE -> CAPEC: CWE-284 -> CAPEC-562
# Checking CAPEC -> Technique: CAPEC-562 -> T1080
# Checking Technique -> Tactic: T1080 -> TA0008
# Checking CWE -> CAPEC: CWE-284 -> CAPEC-564
# Checking CAPEC -> Technique: CAPEC-564 -> T1037
# Checking Technique -> Tactic: T1037 -> TA0003
# Checking Technique -> Tactic: T1037 -> TA0004
# Checking CAPEC -> Technique: CAPEC-564 -> T1543.001
# Checking Technique -> Tactic: T1543.001 -> TA0003
# Checking Technique -> Tactic: T1543.001 -> TA0004
# Checking CAPEC -> Technique: CAPEC-564 -> T1543.004
# Checking Technique -> Tactic: T1543.004 -> TA0003
# Checking Technique -> Tactic: T1543.004 -> TA0004
# Checking CAPEC -> Technique: CAPEC-564 -> T1547
# Checking Technique -> Tactic: T1547 -> TA0003
# Checking Technique -> Tactic: T1547 -> TA0004
